# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
import matplotlib.axes as ax
from sklearn.linear_model import LinearRegression

# %%
v_meter = pd.read_csv(r"http://api.covid19india.org/csv/latest/vaccine_doses_statewise_v2.csv")
v_meter
# Out:
#      Vaccinated As of                        State  First Dose Administered  \
# 0          16/01/2021  Andaman and Nicobar Islands                      225
# 1          16/01/2021               Andhra Pradesh                    18412
# 2          16/01/2021            Arunachal Pradesh                      829
# 3          16/01/2021                        Assam                     3528
# 4          16/01/2021                        Bihar                    18169
# ...               ...                          ...                      ...
# 6379       03/07/2021                Uttar Pradesh                 27780215
# 6380       03/07/2021                  Uttarakhand                  3664348
# 6381       03/07/2021                  West Bengal                 17135555
# 6382       03/07/2021                Miscellaneous                  1736809
# 6383       03/07/2021                        Total                287137161
#
#       Second Dose Administered  Total Doses Administered
# ...

# %%
v_meter.isnull().sum()
# Out:
# Vaccinated As of            0
# State                       0
# First Dose Administered     0
# Second Dose Administered    0
# Total Doses Administered    0
# dtype: int64

# %%
v_meter[v_meter['Vaccinated As of'] == '30/06/2021']
# Out:
#      Vaccinated As of                                     State  \
# 6232       30/06/2021               Andaman and Nicobar Islands
# 6233       30/06/2021                            Andhra Pradesh
# 6234       30/06/2021                         Arunachal Pradesh
# 6235       30/06/2021                                     Assam
# 6236       30/06/2021                                     Bihar
# 6237       30/06/2021                                Chandigarh
# 6238       30/06/2021                              Chhattisgarh
# 6239       30/06/2021  Dadra and Nagar Haveli and Daman and Diu
# 6240       30/06/2021                                     Delhi
# 6241       30/06/2021                                       Goa
# 6242       30/06/2021                                   Gujarat
# 6243       30/06/2021                                   Haryana
# 6244       30/06/2021                          Himachal Pradesh
# 6245       30/06/2021                         Jammu and Kashmir
# ...

# %%
x = v_meter.iloc[6269]['First Dose Administered']
y = v_meter.iloc[6269]['Second Dose Administered']
z = x-y
vaccine_num = (y, z)
plot_labels = ('Fully Vaccinated', 'Partially Vaccinated')
ex_plode = (0.2 , 0)
kolor = ('#5EB0E5', '#7F8B52')

# %%
plt.figure(figsize =(5 , 5))
plt.pie(vaccine_num , explode = ex_plode , shadow = True , colors = kolor , labels =plot_labels , autopct='%1.2f%%')
plt.legend()

# %%
data1 = pd.read_csv(r"http://api.covid19india.org/csv/latest/cowin_vaccine_data_statewise.csv")
data1
# Out:
#       Updated On        State  Total Individuals Vaccinated  \
# 0     16/01/2021        India                       48276.0
# 1     17/01/2021        India                       58604.0
# 2     18/01/2021        India                       99449.0
# 3     19/01/2021        India                      195525.0
# 4     20/01/2021        India                      251280.0
# ...          ...          ...                           ...
# 6286  30/06/2021  West Bengal                    16833029.0
# 6287  01/07/2021  West Bengal                    16900071.0
# 6288  02/07/2021  West Bengal                    17019095.0
# 6289  03/07/2021  West Bengal                    17135494.0
# 6290  04/07/2021  West Bengal                           NaN
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# ...

# %%
male = data1.iloc[167]['Male(Individuals Vaccinated)']
female = data1.iloc[167]['Female(Individuals Vaccinated)']
vaccine_gen = (male, female)
plot_la_bels = ('MALE', 'FEMALE')
ex_plode = (0.05 , 0)
kolor = ('#C46210', '#BC5090')

# %%
plt.figure(figsize =(5 , 5))
plt.pie(vaccine_gen , explode = ex_plode , shadow = True , colors = kolor , labels =plot_la_bels , autopct='%1.2f%%')
plt.legend()

# %%
group1 = data1.iloc[167]['18-45 years (Age)']
group2 = data1.iloc[167]['45-60 years (Age)']
group3 = data1.iloc[167]['60+ years (Age)']
x_axis = [group1 , group2 , group3]
y_axis = ['18-45 years (Age)' , '45-60 years (Age)' , '60+ years (Age)']
plt.figure(figsize=(7 , 7))
plt.bar(y_axis , x_axis , width = 0.5 )
plt.title('Age Group Vaccination Details')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %%
data2 = data1[data1['Updated On'] == '30/06/2021']
data2 = data2[1:]
data2 = data2.sort_values('Total Individuals Vaccinated' , ascending=False )
data2
# Out:
#       Updated On                                     State  \
# 5946  30/06/2021                             Uttar Pradesh
# 3736  30/06/2021                               Maharashtra
# 5096  30/06/2021                                 Rajasthan
# 2036  30/06/2021                                   Gujarat
# 2886  30/06/2021                                 Karnataka
# 3566  30/06/2021                            Madhya Pradesh
# 6286  30/06/2021                               West Bengal
# 1016  30/06/2021                                     Bihar
# 5436  30/06/2021                                Tamil Nadu
# 506   30/06/2021                            Andhra Pradesh
# 3056  30/06/2021                                    Kerala
# 4586  30/06/2021                                    Odisha
# 5606  30/06/2021                                 Telangana
# 2206  30/06/2021                                   Haryana
# 1356  30/06/2021                              Chhattisgarh
# ...

# %%
states = data2['State']
Total = data2['Total Individuals Vaccinated']
plt.figure(figsize=(20 , 10))
plt.bar( states , Total)
plt.title('Statewise Vaccination Details')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.xticks(rotation=60)
plt.show()

# %%
gogo = data1[data1['State'] == 'India']
gogo = gogo.iloc[:-2]
gogo = gogo.iloc[::7]
gogo
# Out:
#      Updated On  State  Total Individuals Vaccinated  \
# 0    16/01/2021  India                       48276.0
# 7    23/01/2021  India                      759008.0
# 14   30/01/2021  India                     3067736.0
# 21   06/02/2021  India                     5111827.0
# 28   13/02/2021  India                     7687352.0
# 35   20/02/2021  India                     9734505.0
# 42   27/02/2021  India                    11141426.0
# 49   06/03/2021  India                    15438495.0
# 56   13/03/2021  India                    23159604.0
# 63   20/03/2021  India                    36568988.0
# 70   27/03/2021  India                    50865316.0
# 77   03/04/2021  India                    63743700.0
# 84   10/04/2021  India                    87411872.0
# 91   17/04/2021  India                   104950409.0
# 98   24/04/2021  India                   117105343.0
# 105  01/05/2021  India                   126328970.0
# 112  08/05/2021  India                   133366482.0
# ...

# %%
Vaccinated_As_of = gogo['Updated On']
Total_Individuals_Vaccinated = gogo['Total Individuals Vaccinated']
First_Dose_Administered = gogo['First Dose Administered']
Second_Dose_Administered = gogo['Second Dose Administered']
plt.figure(figsize=(15 , 10))
plt.plot(Vaccinated_As_of , Total_Individuals_Vaccinated , marker='o' , label = 'First Dose Administered'  )
plt.title('Vaccination Trends')
plt.plot(Vaccinated_As_of , Second_Dose_Administered , marker='o' , label = 'Second Dose Administered '  )
plt.ticklabel_format(style='sci', axis='y', scilimits=(-10000000,100000000))
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
radar = gogo['Total Individuals Vaccinated'].tolist()
radar = list(map(int , radar))
radar.pop(0)
# Out:
# 48276

# %%
#calculating weekly average vaccinations
for i in range(23):
    radar[i] = (radar[i+1]-radar[i])
radar1 = radar[:-1]
weekly_mean = sum(radar1)/len(radar1)
int(weekly_mean)
# Out:
# 12294261

# %%
data1.describe()
# Out:
#        Total Individuals Vaccinated  Total Sessions Conducted  Total Sites   \
# count                  6.252000e+03              6.252000e+03   6252.000000
# mean                   5.082961e+06              3.866433e+05   2371.261996
# std                    2.057662e+07              1.626915e+06   7539.580371
# min                    7.000000e+00              0.000000e+00      0.000000
# 25%                    8.073100e+04              4.300000e+03     70.750000
# 50%                    4.488855e+05              2.448450e+04    616.500000
# 75%                    3.977410e+06              2.567742e+05   1799.250000
# max                    2.835270e+08              3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             6.252000e+03              6.252000e+03
# mean              5.071532e+06              1.118737e+06
# std               2.057375e+07              4.717222e+06
# ...
